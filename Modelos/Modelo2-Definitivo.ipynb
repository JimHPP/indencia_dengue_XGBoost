# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb

from sklearn.metrics import mean_squared_error
paleta_colores = sns.color_palette()
plt.style.use("fivethirtyeight")

import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin'

# %% [markdown]
# # Selección del set de datos y la elección de las columnas a emplear

# %%
dataframe = pd.read_excel(r'C:\Users\harol\Downloads\dataverse_files\Dengue_selected_cities.xlsx', sheet_name = "Maranguape", usecols = ["date", "N_cases","dengue", "a dengue", "sintomas da dengue", "sintomas dengue", "sobre a dengue", "sintomas de dengue", "Mosquito da dengue", "Mosquito Dengue", "dengue hemorragica", "mosquito", "mosquitos" ])
dataframe
# Out:
#           date  N_cases       dengue     a dengue  sintomas da dengue  \
# 0   2010-01-03        0  1127.152461     0.000000            0.000000
# 1   2010-01-10        0   713.816635   717.759975            0.000000
# 2   2010-01-17        1  3228.873453  1793.710458            0.000000
# 3   2010-01-24        0  1370.030551     0.000000            0.000000
# 4   2010-01-31        1  1706.021494   678.469600            0.000000
# ..         ...      ...          ...          ...                 ...
# 339 2016-07-03       10  1689.130975   237.583271          105.560722
# 340 2016-07-10       10  1409.726234   159.577126          132.980914
# 341 2016-07-17        2  1315.260333   219.222446          246.588036
# 342 2016-07-24        3  1439.694825   190.144202          217.288903
# 343 2016-07-31        0  1258.855998   164.238417          273.606916
#
#      sintomas dengue  sobre a dengue  sintomas de dengue  Mosquito da dengue  \
# 0           0.000000        0.000000            0.000000            0.000000
# 1           0.000000        0.000000            0.000000            0.000000
# 2         716.344857      719.146818            0.000000            0.000000
# 3           0.000000        0.000000            0.000000            0.000000
# 4           0.000000        0.000000            0.000000            0.000000
# ..               ...             ...                 ...                 ...
# 339       237.511624       52.842637           52.842637          264.539778
# 340       186.173279      133.141422          106.581394          346.513748
# 341       328.784048       54.863482          109.181508          274.524635
# 342       244.450016      108.775585          135.969482          162.891027
# 343       355.688991       54.787432            0.000000          191.855309
#
#      Mosquito Dengue  dengue hemorragica     mosquito   mosquitos
# 0           0.000000            0.000000   820.942952    0.000000
# 1           0.000000          709.485349     0.000000    0.000000
# 2           0.000000          721.105161     0.000000    0.000000
# 3           0.000000            0.000000  1485.095785  742.547892
# 4           0.000000            0.000000     0.000000    0.000000
# ..               ...                 ...          ...         ...
# 339       291.009735            0.000000   685.268582  114.633280
# 340       373.150069            0.000000   688.085279   86.014986
# 341       274.524635           55.289100   648.263530   58.454207
# 342       162.891027            0.000000   700.420652   58.047813
# 343       219.298712           54.804289   562.561020   59.222595
#
# [344 rows x 13 columns]

# %% [markdown]
# # Selección de las fechas a ser empleada

# %%
dataframe = dataframe.set_index("date")
dataframe = dataframe.loc[ dataframe.index > "2011-01-01"]
dataframe
# Out:
#             N_cases       dengue    a dengue  sintomas da dengue  \
# date
# 2011-01-02        0  1946.924603  169.281152          167.364865
# 2011-01-09        4  2285.845185  487.703462          326.542221
# 2011-01-16        3  2493.439685  756.983953          377.659266
# 2011-01-23        4  1736.280986  157.850214          471.457250
# 2011-01-30        7  3004.378162  237.157645          316.210136
# ...             ...          ...         ...                 ...
# 2016-07-03       10  1689.130975  237.583271          105.560722
# 2016-07-10       10  1409.726234  159.577126          132.980914
# 2016-07-17        2  1315.260333  219.222446          246.588036
# 2016-07-24        3  1439.694825  190.144202          217.288903
# 2016-07-31        0  1258.855998  164.238417          273.606916
#
#             sintomas dengue  sobre a dengue  sintomas de dengue  \
# date
# 2011-01-02       423.139021      167.566875          254.189850
# 2011-01-09       571.448887      164.128556          162.813095
# 2011-01-16       528.722973      151.004695          454.464476
# 2011-01-23       394.565988        0.000000          237.025337
# 2011-01-30       316.210136      316.436483          237.443852
# ...                     ...             ...                 ...
# 2016-07-03       237.511624       52.842637           52.842637
# 2016-07-10       186.173279      133.141422          106.581394
# 2016-07-17       328.784048       54.863482          109.181508
# 2016-07-24       244.450016      108.775585          135.969482
# 2016-07-31       355.688991       54.787432            0.000000
#
#             Mosquito da dengue  Mosquito Dengue  dengue hemorragica  \
# date
# 2011-01-02          167.617453       167.617453          171.862922
# 2011-01-09          488.586716       488.586716            0.000000
# 2011-01-16          151.050275       151.050275          151.900683
# 2011-01-23          314.779184       472.168776            0.000000
# 2011-01-30          792.556077       792.556077          395.287972
# ...                        ...              ...                 ...
# 2016-07-03          264.539778       291.009735            0.000000
# 2016-07-10          346.513748       373.150069            0.000000
# 2016-07-17          274.524635       274.524635           55.289100
# 2016-07-24          162.891027       162.891027            0.000000
# 2016-07-31          191.855309       219.298712           54.804289
#
#                mosquito   mosquitos
# date
# 2011-01-02   457.265145  181.703154
# 2011-01-09   965.925451  175.277175
# 2011-01-16   733.107481    0.000000
# 2011-01-23  1360.958593  512.584618
# 2011-01-30  1018.617656  169.751813
# ...                 ...         ...
# 2016-07-03   685.268582  114.633280
# 2016-07-10   688.085279   86.014986
# 2016-07-17   648.263530   58.454207
# 2016-07-24   700.420652   58.047813
# 2016-07-31   562.561020   59.222595
#
# [292 rows x 12 columns]

# %% [markdown]
# # Gráfico de número de casos de dengue por semana

# %%
dataframe["N_cases"].plot(style=".", figsize=(15, 5), color=paleta_colores[0], title="Casos de dengue semanales")
# Out:
# <AxesSubplot: title={'center': 'Casos de dengue semanales'}, xlabel='date'>

# %% [markdown]
# # Creación de características

# %%
def crear_caracteristicas(dataframe):
    dataframe["week"] = dataframe.index.isocalendar().week
    dataframe["week"] = dataframe["week"].astype(np.int64)
    return dataframe
dataframe = crear_caracteristicas(dataframe)

# %% [markdown]
# # Visualizar características

# %%
fig, ax = plt.subplots(figsize = (20, 8))
sns.boxplot( data = dataframe, x="week", y="N_cases" )
ax.set_title( "Numero_casos por semana" )
# Out:
# Text(0.5, 1.0, 'Numero_casos por semana')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
dataframe = dataframe.drop(["week"], axis = 1)
sns.heatmap(dataframe.corr(), cmap='coolwarm', annot=True, center=0)
plt.show()

# %% [markdown]
# # Crear el modelo

# %%
X, y = dataframe[["dengue", "a dengue", "sintomas da dengue", "sintomas dengue", "sobre a dengue", "sintomas de dengue", "Mosquito da dengue", "Mosquito Dengue", "dengue hemorragica", "mosquito", "mosquitos"]].values, dataframe['N_cases'].values

# %% [markdown]
# ### Partir la data

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(dataframe, test_size=14, shuffle=False)
X_train, y_train = df_train[["dengue", "a dengue", "sintomas da dengue", "sintomas dengue", "sobre a dengue",
                      "sintomas de dengue", "Mosquito da dengue", "Mosquito Dengue", "dengue hemorragica", "mosquito", 
                      "mosquitos"]].values, df_train['N_cases'].values.T
        
X_test, y_test = df_test[["dengue", "a dengue", "sintomas da dengue", "sintomas dengue", "sobre a dengue",
                      "sintomas de dengue", "Mosquito da dengue", "Mosquito Dengue", "dengue hemorragica", "mosquito", 
                      "mosquitos"]].values, df_test['N_cases'].values.T

print ('Training Set: %d rows\nTest Set: %d rows' % (X_train.shape[0], X_test.shape[0]))
# Out:
# Training Set: 278 rows
# Test Set: 14 rows

# %% [markdown]
# ### Creación del modelo empleando el algoritmo XGBoost

# %%
model = xgb.XGBRegressor( n_estimators = 10000, 
                                     max_depth = 7, 
                                     learning_rate = 0.005,
                                    early_stopping_rounds = 10,
                                    num_parallel_tree = 4
                                   )
model.fit(X_train, y_train,
                      eval_set = [ (X_train, y_train),(X_test, y_test) ], 
                      verbose = 20)
# Out:
# [0]	validation_0-rmse:7.88252	validation_1-rmse:11.32705
# [20]	validation_0-rmse:7.28086	validation_1-rmse:10.96742
# [40]	validation_0-rmse:6.72680	validation_1-rmse:10.63778
# [60]	validation_0-rmse:6.22169	validation_1-rmse:10.37568
# [80]	validation_0-rmse:5.76240	validation_1-rmse:10.17620
# [100]	validation_0-rmse:5.33693	validation_1-rmse:9.96724
# [120]	validation_0-rmse:4.94869	validation_1-rmse:9.81608
# [140]	validation_0-rmse:4.59275	validation_1-rmse:9.73618
# [160]	validation_0-rmse:4.26094	validation_1-rmse:9.65210
# [180]	validation_0-rmse:3.96348	validation_1-rmse:9.57340
# [200]	validation_0-rmse:3.69367	validation_1-rmse:9.48683
# [220]	validation_0-rmse:3.44015	validation_1-rmse:9.43661
# [240]	validation_0-rmse:3.20739	validation_1-rmse:9.38157
# [260]	validation_0-rmse:2.99508	validation_1-rmse:9.35645
# [280]	validation_0-rmse:2.79399	validation_1-rmse:9.35019
# [284]	validation_0-rmse:2.75485	validation_1-rmse:9.35208
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=10, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.005, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=7, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=10000,
#              n_jobs=0, num_parallel_tree=4, predictor='auto', random_state=0,
#              reg_alpha=0, reg_lambda=1, ...)

# %%
importancias = model.get_booster().get_score(importance_type='weight')
from xgboost import plot_importance
nombre_caracteristicas = ["dengue", "a dengue", "sintomas da dengue", "sintomas dengue", "sobre a dengue",
                      "sintomas de dengue", "Mosquito da dengue", "Mosquito Dengue", "dengue hemorragica", "mosquito", 
                      "mosquitos"]
i = 0
for caracteristica, importancia in importancias.items():
    print('Característica: %s, Score: %.5f' % ( caracteristica + ":" + nombre_caracteristicas[i], importancia))
    i = i + 1
plt.figure(figsize=(12, 8))
plot_importance(model, importance_type='weight', max_num_features=12)
plt.show()
# Out:
# Característica: f0:dengue, Score: 14276.00000
# Característica: f1:a dengue, Score: 6748.00000
# Característica: f2:sintomas da dengue, Score: 6100.00000
# Característica: f3:sintomas dengue, Score: 5808.00000
# Característica: f4:sobre a dengue, Score: 3684.00000
# Característica: f5:sintomas de dengue, Score: 5440.00000
# Característica: f6:Mosquito da dengue, Score: 3832.00000
# Característica: f7:Mosquito Dengue, Score: 1868.00000
# Característica: f8:dengue hemorragica, Score: 7312.00000
# Característica: f9:mosquito, Score: 5700.00000
# Característica: f10:mosquitos, Score: 5116.00000

# %% [markdown]
# # Pronóstico de predicción

# %%
from sklearn.metrics import mean_squared_error, r2_score
from scipy.stats import pearsonr

# %% [markdown]
# ## Predicción en el modelo en data de prueba

# %%
predictions = model.predict(X_test)
predictions_test = predictions
def relative_root_mean_squared_error(rmse, y_test):    
    den = np.max(y_test) - np.min(y_test)
    return (rmse/den)

mse = mean_squared_error(y_test, predictions)

rmse = np.sqrt(mse)
print("RMSE:", rmse)

r2 = r2_score(y_test, predictions) if r2_score(y_test, predictions) >= 0 else 0.0
print("R2:", r2)

print("R-RMSE:", relative_root_mean_squared_error(rmse, y_test))

print('Correlación de Peason:', pearsonr(y_test, predictions)[0])
# Out:
# RMSE: 9.345848103606432
# R2: 0.0
# R-RMSE: 0.4450403858860206
# Correlación de Peason: 0.05232154604717418

# %%
# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Etiquetas actuales')
plt.ylabel('Etiquetas predecidas')
plt.title('Tendencia de la predicción')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 4))
plt.plot(y_test, label='Esperado')
plt.plot(predictions, label='Predicho')
plt.legend()
plt.show()

# %% [markdown]
# ## Predicción en el modelo en data de entrenamiento

# %%
predictions = model.predict(X_train)

# Display metrics
mse = mean_squared_error(y_train, predictions)

rmse = np.sqrt(mse)

print("RMSE:", rmse)

r2 = r2_score(y_train, predictions) if r2_score(y_train, predictions) >= 0 else 0.0
print("R2:", r2)

print("R-RMSE:", relative_root_mean_squared_error(rmse, y_train))

print('Correlación de Pearson:', pearsonr(y_train, predictions)[0])
# Out:
# RMSE: 2.854252036323216
# R2: 0.8300197570116208
# R-RMSE: 0.08394858930362399
# Correlación de Pearson: 0.9853969321857932

# %%
# Plot predicted vs actual
plt.scatter(y_train, predictions)
plt.xlabel('Etiquetas actuales')
plt.ylabel('Etiquetas predecidas')
plt.title('Tendencia de la predicción')
# overlay the regression line
z = np.polyfit(y_train, predictions, 1)
p = np.poly1d(z)
plt.plot(y_train,p(y_train), color='magenta')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
plt.plot(y_train, label='Esperado')
plt.plot(predictions, label='Predicho')
plt.legend()
plt.show()

# %%
esperado = np.concatenate((y_train, y_test))

fig, ax = plt.subplots(figsize=(12, 6))
# Dibujar y_train
plt.plot(y_train, label='Incidencias históricas', color='blue', alpha=0.6)

# Dibujar y_test
plt.plot(range(len(y_train), len(esperado)), y_test, label='Incidencias esperadas', color='green', alpha=0.6)

# Dibujar la línea donde empieza y_test y predictions
plt.axvline(x=len(y_train), color='grey', linestyle='--', alpha = 0.5)

plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

# Dibujar y_train
plt.plot(y_train, label='Incidencias históricas', color='blue', alpha=0.6)

# Dibujar y_test
plt.plot(range(len(y_train), len(esperado)), predictions_test, label='Incidencias predecidas', color='red', alpha=0.6)

# Dibujar la línea donde empieza y_test y predictions
plt.axvline(x=len(y_train), color='grey', linestyle='--', alpha = 0.5)

plt.legend()
plt.show()
